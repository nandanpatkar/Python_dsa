# %%
arr1 = [ 1,2,3,4]
arr2 = [ 3,4,5,6]


new_a1 = set(arr1)
new_a2 = set(arr2)

list(new_a1 | new_a2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
def union(arr1,arr2):
    result = []


    for num in arr1:
        if num not in result:
            result.append(num)
    for num in arr2:
        if num not in result:
            result.append(num)
    return result           
            
arr1 = [ 1,2,3,4]
arr2 = [ 3,4,5,6]

union(arr1,arr2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
result
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
def union(arr1, arr2):

    s = set(arr1)
    s.update(arr2)

    return list(s)


arr1 = [1,2,2,3]
arr2 = [2,3,4]

print(union(arr1, arr2))
# Out:
# [1, 2, 3, 4]
