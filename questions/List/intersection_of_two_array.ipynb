# %%
arr1 = [1,2,2,1]
arr2 = [2,2]

sarr1= set(arr1)
sarr2 = set(arr2)

# %%
sarr1
# Out:
# {1, 2}

# %%
sarr2
# Out:
# {2}

# %%
list(sarr1.intersection(sarr2))
# Out:
# [2]

# %%
def intersection(arr1, arr2):

    set1 = set(arr1)
    set2 = set(arr2)

    return list(set1 & set2)


arr1 = [1,2,2,1]
arr2 = [2,2]

intersection(arr1,arr2)
# Out:
# [2]

# %%
arr1 = [1,2,2,1]
arr2 = [2,2]

sarr1= set(arr1)
sarr2 = set(arr2)


list(sarr1.intersection(sarr2))
# Out:
# [2]
