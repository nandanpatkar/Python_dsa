# %%
arr = [1,3,4,4,2,2]


def duplicate(arr):
    hash = []
    for i in range(len(arr)):
        for j in range(i+1,len(arr)):
            if arr[i] == arr[j] and arr[i] not in hash:
                hash.append(arr[i])
    return hash            

duplicate(arr)
# Out:
# [4, 2]

# %%
duplicate(arr)
# Out:
# [4, 2]

# %%
# bruitforce 

arr = [1,3,4,2,2]


def duplicate(arr):
    for i in range(len(arr)):
        for j in range(i+1,len(arr)):
            if arr[i] == arr[j]:
                return arr[i]         

duplicate(arr)
# Out:
# 2

# %%
nums = [ 1 ,2 , 2, 3 , 4 , 3 , 5 ]

unique = []
for n in nums:
    if n not in unique:
        unique.append(n)
print(unique)
# Out:
# [1, 2, 3, 4, 5]

# %%
nums = [ 1 ,2 , 2, 3 , 4 , 3 , 5 ]
unique = list(dict.fromkeys(nums))
print(unique)
# Out:
# [1, 2, 3, 4, 5]
