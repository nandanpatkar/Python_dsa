# %%
s1 = "waterbottle"
s2 = "erbottlewat"
s3= s1+s2
if s2 in s3:
    print(True)
else : False
# Out:
# True

# %%
def isRotation(s1, s2):

    if len(s1) != len(s2):
        return False

    return s2 in (s1 + s1)


print(isRotation("waterbottle","erbottlewat"))
# Out:
# True
